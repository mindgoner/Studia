# %% [markdown]
# a) Import bibliotek

# %%
import pandas as pd
import numpy as np
from cryptography.fernet import Fernet
import hashlib
import uuid
from datetime import datetime

# %% [markdown]
# b) Import danych

# %%
df = pd.read_csv('CancerProstateSurvival.csv')
df.head()
# Out:
#    times  patient.vital_status patient.gender patient.race patient.ethnicity  \
# 0    621                     0           male          NaN               NaN
# 1   1332                     0           male          NaN               NaN
# 2    995                     0           male          NaN               NaN
# 3    671                     0           male          NaN               NaN
# 4   1033                     0           male          NaN               NaN
#
#    patient.days_to_birth patient.drugs.drug.therapy_types.therapy_type  \
# 0               -18658.0                                           NaN
# 1               -20958.0                                           NaN
# 2               -17365.0                               hormone therapy
# 3               -19065.0                                           NaN
# 4               -25904.0                                           NaN
#
#    patient.stage_event.pathologic_stage  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
# 0                                                t2b
# 1                                                t3a
# 2                                                 t4
# 3                                                t2b
# 4                                                t3b
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_m
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# c) Identyfikacja danych wrażliwych

# %%
sensitive_cols = ['patient.gender', 'patient.race', 'patient.ethnicity', 'patient.days_to_birth']
clinical_cols = [c for c in df.columns if c not in sensitive_cols]
sensitive_cols, clinical_cols
# Out:
# (['patient.gender',
#   'patient.race',
#   'patient.ethnicity',
#   'patient.days_to_birth'],
#  ['times',
#   'patient.vital_status',
#   'patient.drugs.drug.therapy_types.therapy_type',
#   'patient.stage_event.pathologic_stage',
#   'patient.stage_event.tnm_categories.pathologic_categories.pathologic_t',
#   'patient.stage_event.tnm_categories.pathologic_categories.pathologic_m'])

# %% [markdown]
# d) Szyfrowanie danych (Fernet)

# %%
key = Fernet.generate_key()
fernet = Fernet(key)
df_encrypted = df.copy()
for col in sensitive_cols:
    df_encrypted[col] = df_encrypted[col].astype(str).apply(lambda x: fernet.encrypt(x.encode()).decode())
df_encrypted.head()
# Out:
#    times  patient.vital_status  \
# 0    621                     0
# 1   1332                     0
# 2    995                     0
# 3    671                     0
# 4   1033                     0
#
#                                       patient.gender  \
# 0  gAAAAABpho6kPXqfyGinLyM7TF72yMPlcTJdu4bF0k2Kjo...
# 1  gAAAAABpho6kJw1iSvYAia_rRGgeXFOEUNuyJeXh8L0m7R...
# 2  gAAAAABpho6kXkJrHpdz0y1AL1VNMttNuzN42Wcjn8theh...
# 3  gAAAAABpho6kldbkTadTEbcmHaZfD5GXoHZBgptPHntmQL...
# 4  gAAAAABpho6kHUO1_X6Fl97fp01oI_ioHmd3zKnKd_Dro4...
#
#                                         patient.race  \
# 0  gAAAAABpho6kXV6KBTMj7WllnTwjdkgUuWKbccGxsLAC3j...
# 1  gAAAAABpho6kmdV-IZmkITyyqXAHDOyjbqzbWw6gy_ZomU...
# 2  gAAAAABpho6kCxCwLaaGngOibiFLNnXZj7SZVfunwyJsJ0...
# 3  gAAAAABpho6kCANXTR0FPv5tzFkbDH1mkj5g7UT_jyTscy...
# 4  gAAAAABpho6k2SVhGWnM1kvNzXBg-yAHJmB7fcVvEhP2y2...
#
#                                    patient.ethnicity  \
# 0  gAAAAABpho6kTTQ13QqSG9Nkd_DmUa2zMOevLZKqF0Qyy6...
# 1  gAAAAABpho6kLDg6VowB0OVuZXjNFCiFXoZUNoNFrOWE6C...
# 2  gAAAAABpho6kkWT2-DFt4qEMqd_GtlZrK_cSW85zYOR7iU...
# 3  gAAAAABpho6kD6wKT5y0PbQqTHGNBswdV-T9S5thFEHRlk...
# 4  gAAAAABpho6k3qFcYQJn5Q9ep1rLDKzdvGZutdVYPdu_At...
#
#                                patient.days_to_birth  \
# 0  gAAAAABpho6kv_N3OVCFX1i7xNuKmBoP5hUwHGoQ83tUAB...
# 1  gAAAAABpho6kNv1G-LJ8n5G14HBuidvEJtHE7qvqTiUi4V...
# 2  gAAAAABpho6kU_U00MsIqqivFtHFym98gSB6egMG5d10S7...
# 3  gAAAAABpho6kWTcLAq0Uw3B2de6N5BGA3dbhc_U3AmhiDf...
# 4  gAAAAABpho6kSfTzPV0e0fDp_UvRebozC2VsCCym1KX2nR...
#
#   patient.drugs.drug.therapy_types.therapy_type  \
# 0                                           NaN
# 1                                           NaN
# 2                               hormone therapy
# 3                                           NaN
# 4                                           NaN
#
#    patient.stage_event.pathologic_stage  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
# 0                                                t2b
# 1                                                t3a
# 2                                                 t4
# 3                                                t2b
# 4                                                t3b
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_m
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# e) Integralność danych (SHA-256)

# %%
with open('CancerProstateSurvival.csv', 'rb') as f:
    data_bytes = f.read()
hash_original = hashlib.sha256(data_bytes).hexdigest()
with open('data_hash.sha256', 'w') as f:
    f.write(hash_original)
df_modified = df.copy()
df_modified.iloc[0, 0] = df_modified.iloc[0, 0] + 1
modified_bytes = df_modified.to_csv(index=False).encode()
hash_modified = hashlib.sha256(modified_bytes).hexdigest()
hash_original, hash_modified
# Out:
# ('81fe87a8831a1309bd1fa2d243d10cf791be93a06d8e23cb3c5596c6220fe5bb',
#  '360f9b859e2b6fd5536c0f21ed11886470b3cd462437cfbd6f01aabc144af621')

# %% [markdown]
# f) Pseudonimizacja danych

# %%
df_pseudo = df.copy()
row_tokens = {i: str(uuid.uuid4()) for i in df_pseudo.index}
for col in sensitive_cols:
    df_pseudo[col] = df_pseudo.index.map(row_tokens)
df_pseudo.head()
# Out:
#    times  patient.vital_status                        patient.gender  \
# 0    621                     0  00be0848-52da-4d25-9838-9208996fe619
# 1   1332                     0  dd00fffb-7b49-4058-a761-db5c015196ef
# 2    995                     0  2b44c7b1-77c7-4a08-bc68-52d7129c3680
# 3    671                     0  75aabf28-0513-4635-bb0c-c142c817a203
# 4   1033                     0  25189851-9ea0-4e8a-b631-cd8a3cb5a15e
#
#                            patient.race                     patient.ethnicity  \
# 0  00be0848-52da-4d25-9838-9208996fe619  00be0848-52da-4d25-9838-9208996fe619
# 1  dd00fffb-7b49-4058-a761-db5c015196ef  dd00fffb-7b49-4058-a761-db5c015196ef
# 2  2b44c7b1-77c7-4a08-bc68-52d7129c3680  2b44c7b1-77c7-4a08-bc68-52d7129c3680
# 3  75aabf28-0513-4635-bb0c-c142c817a203  75aabf28-0513-4635-bb0c-c142c817a203
# 4  25189851-9ea0-4e8a-b631-cd8a3cb5a15e  25189851-9ea0-4e8a-b631-cd8a3cb5a15e
#
#                   patient.days_to_birth  \
# 0  00be0848-52da-4d25-9838-9208996fe619
# 1  dd00fffb-7b49-4058-a761-db5c015196ef
# 2  2b44c7b1-77c7-4a08-bc68-52d7129c3680
# 3  75aabf28-0513-4635-bb0c-c142c817a203
# 4  25189851-9ea0-4e8a-b631-cd8a3cb5a15e
#
#   patient.drugs.drug.therapy_types.therapy_type  \
# 0                                           NaN
# 1                                           NaN
# 2                               hormone therapy
# 3                                           NaN
# 4                                           NaN
#
#    patient.stage_event.pathologic_stage  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
# 0                                                t2b
# 1                                                t3a
# 2                                                 t4
# 3                                                t2b
# 4                                                t3b
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_m
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# g) Anonimizacja danych

# %%
df_anon = df.copy()
age_years = (-df_anon['patient.days_to_birth'] / 365.25).round(0)
df_anon['age_group'] = pd.cut(age_years, bins=[0, 50, 60, 70, 80, 200], labels=['0-50','51-60','61-70','71-80','81+'])
df_anon = df_anon.drop(columns=sensitive_cols)
df_anon.head()
# Out:
#    times  patient.vital_status patient.drugs.drug.therapy_types.therapy_type  \
# 0    621                     0                                           NaN
# 1   1332                     0                                           NaN
# 2    995                     0                               hormone therapy
# 3    671                     0                                           NaN
# 4   1033                     0                                           NaN
#
#    patient.stage_event.pathologic_stage  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
# 0                                                t2b
# 1                                                t3a
# 2                                                 t4
# 3                                                t2b
# 4                                                t3b
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_m  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   age_group
# 0     51-60
# 1     51-60
# 2      0-50
# 3     51-60
# 4     71-80

# %% [markdown]
# h) Kontrola dostępu (RBAC)

# %%
roles = {
    'administrator': df.columns.tolist(),
    'lekarz': clinical_cols + ['patient.gender'],
    'analityk': clinical_cols
}
def access_data(role):
    cols = roles[role]
    return df[cols]
access_admin = access_data('administrator').head()
access_doctor = access_data('lekarz').head()
access_analyst = access_data('analityk').head()
access_admin, access_doctor, access_analyst
# Out:
# (   times  patient.vital_status patient.gender patient.race patient.ethnicity  \
#  0    621                     0           male          NaN               NaN
#  1   1332                     0           male          NaN               NaN
#  2    995                     0           male          NaN               NaN
#  3    671                     0           male          NaN               NaN
#  4   1033                     0           male          NaN               NaN
#
#     patient.days_to_birth patient.drugs.drug.therapy_types.therapy_type  \
#  0               -18658.0                                           NaN
#  1               -20958.0                                           NaN
#  2               -17365.0                               hormone therapy
#  3               -19065.0                                           NaN
#  4               -25904.0                                           NaN
#
#     patient.stage_event.pathologic_stage  \
#  0                                   NaN
#  1                                   NaN
#  2                                   NaN
#  3                                   NaN
#  4                                   NaN
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
#  0                                                t2b
#  1                                                t3a
#  2                                                 t4
#  3                                                t2b
#  4                                                t3b
#
#     patient.stage_event.tnm_categories.pathologic_categories.pathologic_m
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN                      ,
#     times  patient.vital_status patient.drugs.drug.therapy_types.therapy_type  \
#  0    621                     0                                           NaN
#  1   1332                     0                                           NaN
#  2    995                     0                               hormone therapy
#  3    671                     0                                           NaN
#  4   1033                     0                                           NaN
#
#     patient.stage_event.pathologic_stage  \
#  0                                   NaN
#  1                                   NaN
#  2                                   NaN
#  3                                   NaN
#  4                                   NaN
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
#  0                                                t2b
#  1                                                t3a
#  2                                                 t4
#  3                                                t2b
#  4                                                t3b
#
#     patient.stage_event.tnm_categories.pathologic_categories.pathologic_m  \
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN
#
#    patient.gender
#  0           male
#  1           male
#  2           male
#  3           male
#  4           male  ,
#     times  patient.vital_status patient.drugs.drug.therapy_types.therapy_type  \
#  0    621                     0                                           NaN
#  1   1332                     0                                           NaN
#  2    995                     0                               hormone therapy
#  3    671                     0                                           NaN
#  4   1033                     0                                           NaN
#
#     patient.stage_event.pathologic_stage  \
#  0                                   NaN
#  1                                   NaN
#  2                                   NaN
#  3                                   NaN
#  4                                   NaN
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
#  0                                                t2b
#  1                                                t3a
#  2                                                 t4
#  3                                                t2b
#  4                                                t3b
#
#     patient.stage_event.tnm_categories.pathologic_categories.pathologic_m
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN                      )

# %% [markdown]
# i) Audyt dostępu do danych

# %%
audit_log = []
def log_access(role, cols):
    audit_log.append({
        'time': datetime.utcnow().isoformat(),
        'role': role,
        'columns': ','.join(cols)
    })
for role in roles:
    cols = roles[role]
    _ = df[cols].head()
    log_access(role, cols)
audit_df = pd.DataFrame(audit_log)
audit_df
# Out:
#                          time           role  \
# 0  2026-02-07T01:00:20.580726  administrator
# 1  2026-02-07T01:00:20.580726         lekarz
# 2  2026-02-07T01:00:20.580726       analityk
#
#                                              columns
# 0  times,patient.vital_status,patient.gender,pati...
# 1  times,patient.vital_status,patient.drugs.drug....
# 2  times,patient.vital_status,patient.drugs.drug....

# %% [markdown]
# j) Walidacja i ochrona danych wejściowych

# %%
with open('CancerProstateSurvival.csv', 'rb') as f:
    current_hash = hashlib.sha256(f.read()).hexdigest()
if current_hash != hash_original:
    raise ValueError('Wykryto manipulacje danych')
df_verified = pd.read_csv('CancerProstateSurvival.csv')
df_verified.head()
# Out:
#    times  patient.vital_status patient.gender patient.race patient.ethnicity  \
# 0    621                     0           male          NaN               NaN
# 1   1332                     0           male          NaN               NaN
# 2    995                     0           male          NaN               NaN
# 3    671                     0           male          NaN               NaN
# 4   1033                     0           male          NaN               NaN
#
#    patient.days_to_birth patient.drugs.drug.therapy_types.therapy_type  \
# 0               -18658.0                                           NaN
# 1               -20958.0                                           NaN
# 2               -17365.0                               hormone therapy
# 3               -19065.0                                           NaN
# 4               -25904.0                                           NaN
#
#    patient.stage_event.pathologic_stage  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   patient.stage_event.tnm_categories.pathologic_categories.pathologic_t  \
# 0                                                t2b
# 1                                                t3a
# 2                                                 t4
# 3                                                t2b
# 4                                                t3b
#
#    patient.stage_event.tnm_categories.pathologic_categories.pathologic_m
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
